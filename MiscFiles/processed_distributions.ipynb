# %%
# Group 5
# Neel Gandhi, Sunishka Jain, Daniel Shen, Julian Wu
#This is just to get a sense of the distributions of the data

# Imports
import pandas as pd
import glob
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import data

file = './processedData.csv'
data = pd.read_csv(file)

# %%
import numpy as np

from scipy.stats import uniform, randint
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, RandomizedSearchCV, train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import xgboost as xgb

# %%
convert_feature = ['cDNA_position','CDS_position','Protein_position']
data['cDNA_position'] = data['cDNA_position'].astype(str).str.replace(r'\D+', '')
data['CDS_position'] = data['CDS_position'].astype(str).str.replace(r'\D+', '')
data['Protein_position'] = data['Protein_position'].astype(str).str.replace(r'\D+', '')
for i in range(len(convert_feature)):
    data[convert_feature[i]] = data[convert_feature[i]].astype(int)

# %%
#Dropping the first column because it does not represent meaningful data
data = data.iloc[: , 1:]

# %%
for column in data:
    fig, ax = plt.subplots(1,1, figsize=(15, 6))
    sns.kdeplot(data[column]).set(title=str(column))
    #sns.kdeplot(y = data[i][1:],data=data.iloc[1:], order=data[i][1:].value_counts().index, palette='Blues_r')
    #fig.text(0.1, 0.95, f'{df[i][0].split("(")[0]}', fontsize=16, fontweight='bold', fontfamily='serif')
    plt.xlabel(' ', fontsize=20)
    plt.ylabel('')
    plt.yticks(fontsize=13)
    plt.box(False)
# Out:
# <ipython-input-44-1db85565c39d>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(1,1, figsize=(15, 6))
# /Users/danielshen/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/danielshen/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/danielshen/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/danielshen/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
#Printing the ranges of each of the columns
data.min(axis=0)
# for i in range(len(data.axes[1])):
#     data[].max(axis=0)
# Out:
# CHROM                                                     1.000000
# POS                                                  193245.000000
# REF                                                       1.000000
# ALT                                                       1.000000
# AF_ESP                                                    0.000000
# AF_EXAC                                                   0.000000
# AF_TGP                                                    0.000000
# CLNVC                                                     0.000000
# CLASS                                                     0.000000
# IMPACT                                                    0.000000
# SYMBOL                                                    4.000000
# cDNA_position                                             2.000000
# CDS_position                                              1.000000
# Protein_position                                          1.000000
# STRAND                                                   -1.000000
# SIFT                                                      0.000000
# PolyPhen                                                  0.000000
# LoFtool                                                   0.000069
# CADD_PHRED                                                0.001000
# CADD_RAW                                                 -5.477391
# Amino_acid_ref                                            1.000000
# Amino_acid_alt                                            1.000000
# unknown                                                   0.000000
# germline                                                  0.000000
# somatic                                                   0.000000
# inherited                                                 0.000000
# paternal                                                  0.000000
# maternal                                                  0.000000
# de-novo                                                   0.000000
# biparental                                                0.000000
# uniparental                                               0.000000
# not-tested                                                0.000000
# tested-inconclusive                                       0.000000
# other_origin                                              0.000000
# missense_variant                                          0.000000
# synonymous_variant                                        0.000000
# other                                                     0.000000
# IE                                                        1.000000
# IELOCATION                                                0.005510
# has_Hereditary_cancer-predisposing_syndrome               0.000000
# has_Hereditary_breast_and_ovarian_cancer_syndrome         0.000000
# has_Familial_cancer_of_breast                             0.000000
# has_Dilated_cardiomyopathy_1G                             0.000000
# has_Limb-girdle_muscular_dystrophy,_type_2J               0.000000
# has_Cardiovascular_phenotype                              0.000000
# has_Hypertrophic_cardiomyopathy                           0.000000
# has_Ataxia-telangiectasia_syndrome                        0.000000
# has_Hereditary_nonpolyposis_colon_cancer                  0.000000
# has_Dilated_Cardiomyopathy,_Dominant                      0.000000
# has_Familial_hypercholesterolemia                         0.000000
# has_Breast-ovarian_cancer,_familial_2                     0.000000
# has_Familial_adenomatous_polyposis_1                      0.000000
# has_Limb-Girdle_Muscular_Dystrophy,_Recessive             0.000000
# has_Lynch_syndrome                                        0.000000
# dtype: float64

# %%
data.max(axis=0)
# Out:
# CHROM                                                2.300000e+01
# POS                                                  2.476080e+08
# REF                                                  5.000000e+00
# ALT                                                  5.000000e+00
# AF_ESP                                               4.990000e-01
# AF_EXAC                                              4.998900e-01
# AF_TGP                                               4.998000e-01
# CLNVC                                                5.000000e+00
# CLASS                                                1.000000e+00
# IMPACT                                               3.000000e+00
# SYMBOL                                               2.328000e+03
# cDNA_position                                        1.060121e+11
# CDS_position                                         1.057871e+11
# Protein_position                                     3.185032e+09
# STRAND                                               1.000000e+00
# SIFT                                                 3.000000e+00
# PolyPhen                                             3.000000e+00
# LoFtool                                              1.000000e+00
# CADD_PHRED                                           9.900000e+01
# CADD_RAW                                             4.655626e+01
# Amino_acid_ref                                       2.400000e+01
# Amino_acid_alt                                       2.400000e+01
# unknown                                              1.000000e+00
# germline                                             1.000000e+00
# somatic                                              1.000000e+00
# inherited                                            1.000000e+00
# paternal                                             1.000000e+00
# maternal                                             1.000000e+00
# de-novo                                              1.000000e+00
# biparental                                           1.000000e+00
# uniparental                                          0.000000e+00
# not-tested                                           0.000000e+00
# tested-inconclusive                                  1.000000e+00
# other_origin                                         0.000000e+00
# missense_variant                                     1.000000e+00
# synonymous_variant                                   1.000000e+00
# other                                                1.000000e+00
# IE                                                   1.000000e+00
# IELOCATION                                           1.000000e+00
# has_Hereditary_cancer-predisposing_syndrome          1.000000e+00
# has_Hereditary_breast_and_ovarian_cancer_syndrome    1.000000e+00
# has_Familial_cancer_of_breast                        1.000000e+00
# has_Dilated_cardiomyopathy_1G                        1.000000e+00
# has_Limb-girdle_muscular_dystrophy,_type_2J          1.000000e+00
# has_Cardiovascular_phenotype                         1.000000e+00
# has_Hypertrophic_cardiomyopathy                      1.000000e+00
# has_Ataxia-telangiectasia_syndrome                   1.000000e+00
# has_Hereditary_nonpolyposis_colon_cancer             1.000000e+00
# has_Dilated_Cardiomyopathy,_Dominant                 1.000000e+00
# has_Familial_hypercholesterolemia                    1.000000e+00
# has_Breast-ovarian_cancer,_familial_2                1.000000e+00
# has_Familial_adenomatous_polyposis_1                 1.000000e+00
# has_Limb-Girdle_Muscular_Dystrophy,_Recessive        1.000000e+00
# has_Lynch_syndrome                                   1.000000e+00
# dtype: float64
